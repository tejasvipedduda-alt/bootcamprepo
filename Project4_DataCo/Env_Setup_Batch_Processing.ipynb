# %%
# %sql
-- Creating external location for the ADLS 
CREATE EXTERNAL LOCATION IF NOT EXISTS datacoexternallocation
    URL 'abfss://dataco@bootcampprj1adlssynapse.dfs.core.windows.net/landing'
    WITH (STORAGE CREDENTIAL nycyellowtripcredential)
    COMMENT 'This is the external location for the DataCo Supply Chain data';

# %%
# %python
#Checking if I have access to the adls storage location
dbutils.fs.ls("abfss://dataco@bootcampprj1adlssynapse.dfs.core.windows.net/landing/")

# %%
# %sql
-- Creating catalog in the managed location
CREATE CATALOG IF NOT EXISTS dataco
MANAGED LOCATION 'abfss://dataco@bootcampprj1adlssynapse.dfs.core.windows.net/landing/';

USE CATALOG dataco;

# %%
# %sql
-- creating schema 
CREATE SCHEMA IF NOT EXISTS landing
COMMENT 'This is the schema for the dataco data';

USE SCHEMA landing;

# %%
# %sql
CREATE VOLUME IF NOT EXISTS landing.raw;

# %%
# %sql
-- Creating Bronze, Silver and Gold schema 
CREATE SCHEMA IF NOT EXISTS bronze;
CREATE SCHEMA IF NOT EXISTS silver;
CREATE SCHEMA IF NOT EXISTS gold;
