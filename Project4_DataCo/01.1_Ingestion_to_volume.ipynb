# %%
# %pip install kaggle

# %%
dbutils.library.restartPython()

# %%
import os

os.environ["KAGGLE_USERNAME"] = "tejasvipeddu"
os.environ["KAGGLE_KEY"] = "dd875c9e54389dcd04c94726119de17b"

# %%
from kaggle.api.kaggle_api_extended import KaggleApi

api = KaggleApi()
api.authenticate()

# %%
volume_path = "/Volumes/dataco/landing/raw"

api.dataset_download_files(
    "alinoranianesfahani/dataco-smart-supply-chain-for-big-data-analysis",
    path=volume_path,
    unzip=True
)

# %%
api.dataset_list_files(
    "alinoranianesfahani/dataco-smart-supply-chain-for-big-data-analysis"
)

# %%
print(volume_path)

# %%
display(dbutils.fs.ls("/Volumes/dataco/landing/raw/"))
