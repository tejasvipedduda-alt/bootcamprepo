-- %%
-- Creating external location for the ADLS 
CREATE EXTERNAL LOCATION IF NOT EXISTS nycyellotripexternallocation
    URL 'abfss://nycyellowtripdata@bootcampporjectadls.dfs.core.windows.net/'
    WITH (STORAGE CREDENTIAL nycyellowtripcredential)
    COMMENT 'This is the external location for the yellow taxi data';

-- %%
%python
#Checking if I have access to the adls storage location
dbutils.fs.ls("abfss://nycyellowtripdata@bootcampporjectadls.dfs.core.windows.net/")

-- %%
-- Creating catalog in the managed location
CREATE CATALOG IF NOT EXISTS nycyellow
MANAGED LOCATION 'abfss://nycyellowtripdata@bootcampporjectadls.dfs.core.windows.net/';

USE CATALOG nycyellow;

-- %%
-- creating schema 
CREATE SCHEMA IF NOT EXISTS landing
COMMENT 'This is the schema for the yellow taxi data';

USE SCHEMA landing;

-- %%
CREATE VOLUME IF NOT EXISTS landing.raw;

-- %%
-- Creating Bronze, Silver and Gold schema 
CREATE SCHEMA IF NOT EXISTS bronze;
CREATE SCHEMA IF NOT EXISTS silver;
CREATE SCHEMA IF NOT EXISTS gold;
