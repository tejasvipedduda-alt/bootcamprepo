-- %%
-- Creating external location for retail rocket ADLS 
CREATE EXTERNAL LOCATION IF NOT EXISTS retailrocketexternallocation
    URL 'abfss://retailrocket@bootcampporjectadls.dfs.core.windows.net/'
    WITH (STORAGE CREDENTIAL retailrocketcredential)
    COMMENT 'This is the external location for the retail rocket data';

-- %%
CREATE CATALOG IF NOT EXISTS retrailrocket
MANAGED LOCATION 'abfss://retailrocket@bootcampporjectadls.dfs.core.windows.net/';

USE CATALOG retrailrocket;

-- %%
-- creating schema
CREATE SCHEMA IF NOT EXISTS landing;
CREATE SCHEMA IF NOT EXISTS bronze;
CREATE SCHEMA IF NOT EXISTS silver;
CREATE SCHEMA IF NOT EXISTS gold;

-- %%
-- creating volume in ADLS
CREATE VOLUME IF NOT EXISTS landing.raw
COMMENT 'landing zone for raw data';
